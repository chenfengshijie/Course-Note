# %% [markdown]
# # 简单的图片操作

# %%
'''
Author: 495964337 495964337@qq.com
Date: 2022-11-19 13:12:45
LastEditors: 495964337 495964337@qq.com
LastEditTime: 2022-11-19 13:26:09
FilePath: \Courses\python\First：基本图像操作和处理.ipynb
Description: 这是默认设置,请设置`customMade`, 打开koroFileHeader查看配置 进行设置: https://github.com/OBKoro1/koro1FileHeader/wiki/%E9%85%8D%E7%BD%AE
'''
#-*-codings:utf-8
from PIL import Image
import os
from matplotlib import pyplot as plt

def open_save_img(filepath):
    """open and save image file

    Args:
        filepath (str): a file path
    """
    img = Image.open(filepath)
    plt.axis("off")
    plt.subplot(121)
    plt.axis("off")
    plt.imshow(img)
    # use convert to convert a RGB img into gray image
    pil_img = img.convert("L")
    pil_img.save("gray"+filepath)
    plt.subplot(122)
    plt.axis("off")
    plt.imshow(pil_img,cmap="gray")
    plt.show()

open_save_img("4_makeup_4k.jpg")

# %%
def crop_thumbnail_rotate(img):

    # generate thumbnails
    thumbnail_img = img.thumbnail((128,128))
    # crop img and paste into original image
    box = (100,100,400,400)
    region = img.crop(box)
    region = region.transpose(Image.ROTATE_180)
    img.paste(region,box)
    plt.imshow(img)
    plt.show()

img = Image.open("4_makeup_4k.jpg")

# %%
def histeq(im,nbr_bins=256):
    """对一灰度图进行直方图均衡化

    Args:
        im (PIL.image): _description_
        nbr_bins (int, optional): _description_. Defaults to 256.
    """
    imhist,bins =
